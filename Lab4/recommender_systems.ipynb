# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
jester = pd.read_csv('https://raw.githubusercontent.com/albanda/CE888/master/lab4-recommender/jester-data-1.csv', header=None)
jester.head()
# Out:
#    0      1      2      3      4    ...    96     97     98     99     100
# 0   74  -7.82   8.79  -9.66  -8.16  ...  99.00  -5.63  99.00  99.00  99.00
# 1  100   4.08  -0.29   6.36   4.37  ...  -2.14   3.06   0.34  -4.32   1.07
# 2   49  99.00  99.00  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 3   48  99.00   8.35  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 4   91   8.50   4.61  -4.17  -5.39  ...   1.55   3.11   6.55   1.80   1.60
#
# [5 rows x 101 columns]

# %%
jester.describe().transpose()
# Out:
#        count       mean        std    min     25%    50%    75%    max
# 0    24983.0  72.467478  21.859600  36.00  53.000  72.00  100.0  100.0
# 1    24983.0  34.401435  46.707059  -9.95  -0.150   5.05   99.0   99.0
# 2    24983.0  27.094089  44.228006  -9.95  -2.180   3.69   99.0   99.0
# 3    24983.0  33.263717  46.747535  -9.95  -1.145   4.66   99.0   99.0
# 4    24983.0  36.244936  48.812967  -9.95  -3.350   3.45   99.0   99.0
# ..       ...        ...        ...    ...     ...    ...    ...    ...
# 96   24983.0  58.541104  48.130562  -9.95   3.300  99.00   99.0   99.0
# 97   24983.0  58.017246  48.164681  -9.95   3.590  99.00   99.0   99.0
# 98   24983.0  57.061650  48.717455  -9.95   2.670  99.00   99.0   99.0
# 99   24983.0  55.753357  49.237139  -9.95   1.335  99.00   99.0   99.0
# 100  24983.0  60.138090  47.913531  -9.95   3.930  99.00   99.0   99.0
#
# [101 rows x 8 columns]

# %%
jester_nan = jester.replace(99, np.nan)

# %%
jester_nan.isna().sum()
# Out:
# 0         81
# 1       8531
# 2       6799
# 3       8341
# 4       9375
#        ...
# 96     14613
# 97     14463
# 98     14317
# 99     14073
# 100    15040
# Length: 101, dtype: int64

# %%
len(jester[0].unique())
# Out:
# 65

# %%
jester_nan.drop(columns=0, axis=1, inplace=True)

# %%
jester_nan.head()
# Out:
#     1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0 -7.82  8.79 -9.66 -8.16 -7.52 -8.50  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1  4.08 -0.29  6.36  4.37 -2.38 -9.66  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2   NaN   NaN   NaN   NaN  9.03  9.27  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  8.35   NaN   NaN  1.80  8.16  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4  8.50  4.61 -4.17 -5.39  1.36  1.60  ...  5.73  1.55  3.11  6.55  1.80  1.60
#
# [5 rows x 100 columns]

# %%
jester_nan.mean()
# Out:
# 1      0.904573
# 2      0.208460
# 3      0.316574
# 4     -1.449114
# 5      0.403556
#          ...
# 96     1.528003
# 97     1.673750
# 98     0.767692
# 99    -0.031244
# 100    1.354711
# Length: 100, dtype: float64

# %%
arr = jester_nan.values

# %%
np.where(arr!= 99)
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([ 0,  1,  2, ..., 97, 98, 99]))

# %%
def helper_function(orig, percentage=0.1):
  """
  Replaces 'percentage'% of the original values in 'orig' with 99's
  :param orig: original data array
  :param percentage: percentage of values to replace (0<percentage<1)
  """
  new_data = orig.copy()
  rated = np.where(~np.isnan(orig))
  n_rated = len(rated[0])
  idx = np.random.choice(n_rated, size=int(percentage*n_rated), replace=False)
  new_data[rated[0][idx], rated[1][idx]] = 99
  return new_data, (rated[0][idx], rated[1][idx])

# %%
new_arr, idx = helper_function(arr)

# %%
arr[idx[0][0], idx[1][0]]
# Out:
# -0.39

# %%
new_arr[idx[0][0], idx[1][0]]
# Out:
# 99.0

# %%
jester.groupby(0).count()
# Out:
#       1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0                                        ...
# 36    482   482   482   482   482   482  ...   482   482   482   482   482   482
# 37    409   409   409   409   409   409  ...   409   409   409   409   409   409
# 38    413   413   413   413   413   413  ...   413   413   413   413   413   413
# 39    391   391   391   391   391   391  ...   391   391   391   391   391   391
# 40    407   407   407   407   407   407  ...   407   407   407   407   407   407
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 96     68    68    68    68    68    68  ...    68    68    68    68    68    68
# 97     60    60    60    60    60    60  ...    60    60    60    60    60    60
# 98     71    71    71    71    71    71  ...    71    71    71    71    71    71
# 99     81    81    81    81    81    81  ...    81    81    81    81    81    81
# 100  7200  7200  7200  7200  7200  7200  ...  7200  7200  7200  7200  7200  7200
#
# [65 rows x 100 columns]

# %%
users = jester[0].unique()
users
# Out:
# array([ 74, 100,  49,  48,  91,  47,  72,  36,  51,  53,  55,  50,  67,
#         60,  54,  46,  38,  41,  73,  92,  89,  71,  40,  45,  62,  63,
#         61,  65,  68,  69,  37,  56,  66,  64,  82,  57,  75,  88,  86,
#         43,  83,  93,  94,  44,  59,  39,  58,  70,  78,  97,  90,  84,
#         98,  96,  52,  80,  42,  81,  76,  79,  85,  77,  95,  87,  99])

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = latent_user_preferences[user_id]
    item_preference = latent_item_features[item_id]
    return user_preference.dot(item_preference)


def train(user_id, item_id, rating, alpha=0.0001):
    #print(item_id)
    predicted_rating = predict_rating(user_id, item_id)
    err =  predicted_rating - rating
    #print(err)
    user_pref_values = latent_user_preferences[user_id]
    latent_user_preferences[user_id] -= alpha * err * latent_item_features[item_id]
    latent_item_features[item_id] -= alpha * err * user_pref_values
    return err
    

def sgd(iterations):
    """ Iterate over all users and all items and train for 
        a certain number of iterations
    """
    mse_history = []
    for iteration in range(iterations):
        error = []
        for user_id in range(latent_user_preferences.shape[0]):
            for item_id in range(latent_item_features.shape[0]):
                rating = user_ratings[user_id, item_id]
                if not np.isnan(rating):
                    err = train(user_id, item_id, rating)
                    error.append(err)
        mse = (np.array(error) ** 2).mean()   
        if (iteration % 5) == 0:
            print('Iteration %d/%d:\tMSE=%.6f' % (iteration, iterations, mse))
            mse_history.append(mse)
    return mse_history

# %%
n_latent_factors = 4

user_ratings = jester_nan.values
# Initialise as random values
latent_user_preferences = np.random.random((user_ratings.shape[0], n_latent_factors))
latent_item_features = np.random.random((user_ratings.shape[1], n_latent_factors))

# %% [markdown]
# # MSE of validation set

# %%
err  =[]
for u, i in zip(*idx):
  err.append(predict_rating(u,i) - user_ratings[u,i])
print('MSE of validation set: ', (np.array(err)**2).mean())
# Out:
# MSE of validation set:  27.581273926595994

# %% [markdown]
# # Prediction of test set

# %%
test_idx = np.where(np.isnan(user_ratings))
for u, i in zip(*test_idx):
  print('Prediction for {} user_id for item_id {} is {}'.format(u, i, predict_rating(u,i)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction for 24812 user_id for item_id 92 is 0.536981127643963
# Prediction for 24812 user_id for item_id 93 is 1.2887059905553322
# Prediction for 24812 user_id for item_id 94 is 0.5592035857734504
# Prediction for 24812 user_id for item_id 95 is 0.5430324367728291
# Prediction for 24813 user_id for item_id 70 is 0.8210745120809793
# Prediction for 24813 user_id for item_id 71 is 0.33343756604260794
# Prediction for 24813 user_id for item_id 72 is 0.4265008496987498
# Prediction for 24813 user_id for item_id 73 is 0.4821353477004781
# Prediction for 24813 user_id for item_id 74 is 0.4817486694308691
# Prediction for 24813 user_id for item_id 75 is 0.9902757413889035
# Prediction for 24813 user_id for item_id 76 is 1.4497246270109867
# Prediction for 24813 user_id for item_id 77 is 1.1835876883456042
# Prediction for 24813 user_id for item_id 78 is 0.8749137135848645
# Prediction for 24813 user_id for item_id 79 is 1.5835419510501603
# Prediction for 24813 user_id for item_id 80 is 0.7057491389529423
# Prediction for 24813 user_id for item_id 81 is 0.7686821281240357
# Prediction for 24813 user_id for item_id 83 is 1.7429964244506058
# Prediction for 24813 user_id for item_id 85 is 0.794930749095981
# Prediction for 24813 user_id for item_id 86 is 0.5330302067709988
# Prediction for 24813 user_id for item_id 87 is 0.692558015704077
# Prediction for 24813 user_id for item_id 88 is 0.5500289464143389
# Prediction for 24813 user_id for item_id 89 is 0.9552532238315082
# Prediction for 24813 user_id for item_id 90 is 1.2402627013033654
# Prediction for 24813 user_id for item_id 91 is 0.23880939353628475
# Prediction for 24813 user_id for item_id 92 is 0.6968948871032383
# Prediction for 24813 user_id for item_id 93 is 1.614770372848733
# Prediction for 24813 user_id for item_id 95 is 0.45145338981180017
# Prediction for 24813 user_id for item_id 96 is 1.0087312758919427
# Prediction for 24813 user_id for item_id 97 is 1.2424978168194736
# Prediction for 24813 user_id for item_id 98 is 0.7112554807099385
# Prediction for 24813 user_id for item_id 99 is 0.6522621792113655
# Prediction for 24814 user_id for item_id 0 is 0.2846102317707037
# Prediction for 24814 user_id for item_id 1 is 0.4203520130211937
# Prediction for 24814 user_id for item_id 2 is 0.36727788035525744
# Prediction for 24814 user_id for item_id 3 is 0.3155701056517128
# Prediction for 24814 user_id for item_id 5 is 0.518699357651972
# Prediction for 24814 user_id for item_id 8 is 0.3569894800032288
# Prediction for 24814 user_id for item_id 9 is 0.1670625004146905
# Prediction for 24814 user_id for item_id 10 is 0.42632502329999505
# Prediction for 24814 user_id for item_id 11 is 0.4422114010112055
# Prediction for 24814 user_id for item_id 13 is 0.234853030727603
# Prediction for 24814 user_id for item_id 21 is 0.33179218692962
# Prediction for 24814 user_id for item_id 22 is 0.45190274567791605
# Prediction for 24814 user_id for item_id 23 is 0.5418779004614296
# Prediction for 24814 user_id for item_id 24 is 0.23452522585450994
# Prediction for 24814 user_id for item_id 25 is 0.3213194152327824
# Prediction for 24814 user_id for item_id 28 is 0.46289844679925285
# Prediction for 24814 user_id for item_id 29 is 0.2831205452448154
# Prediction for 24814 user_id for item_id 32 is 0.4184652179978219
# Prediction for 24814 user_id for item_id 36 is 0.2969526437755579
# Prediction for 24814 user_id for item_id 37 is 0.3690578998447712
# Prediction for 24814 user_id for item_id 38 is 0.35482094856064317
# Prediction for 24814 user_id for item_id 40 is 0.21995117917012463
# Prediction for 24814 user_id for item_id 42 is 0.28906966230379205
# Prediction for 24814 user_id for item_id 43 is 0.35690355951895397
# Prediction for 24814 user_id for item_id 44 is 0.4099476613990237
# Prediction for 24814 user_id for item_id 50 is 0.2973404263530734
# Prediction for 24814 user_id for item_id 51 is 0.15887974209633024
# Prediction for 24814 user_id for item_id 53 is 0.22879688531321227
# Prediction for 24814 user_id for item_id 54 is 0.15415869400134505
# Prediction for 24814 user_id for item_id 56 is 0.322572263867173
# Prediction for 24814 user_id for item_id 57 is 0.46106566756807715
# Prediction for 24814 user_id for item_id 58 is 0.2784715852308277
# Prediction for 24814 user_id for item_id 59 is 0.5769861714554011
# Prediction for 24814 user_id for item_id 62 is 0.36302079764900036
# Prediction for 24814 user_id for item_id 63 is 0.383695769721581
# Prediction for 24814 user_id for item_id 66 is 0.5049282883106893
# Prediction for 24814 user_id for item_id 71 is 0.13299255910987873
# Prediction for 24814 user_id for item_id 72 is 0.14580564033797708
# Prediction for 24814 user_id for item_id 73 is 0.2047631080567954
# Prediction for 24814 user_id for item_id 74 is 0.10741546671479714
# Prediction for 24814 user_id for item_id 75 is 0.20834686828698223
# Prediction for 24814 user_id for item_id 76 is 0.5296442377283432
# Prediction for 24814 user_id for item_id 77 is 0.33169856071512704
# Prediction for 24814 user_id for item_id 78 is 0.37110364230608045
# Prediction for 24814 user_id for item_id 79 is 0.5309888691155278
# Prediction for 24814 user_id for item_id 80 is 0.17105660424636862
# Prediction for 24814 user_id for item_id 81 is 0.189016209595086
# Prediction for 24814 user_id for item_id 82 is 0.3873000197082504
# Prediction for 24814 user_id for item_id 83 is 0.5379620570544592
# Prediction for 24814 user_id for item_id 84 is 0.49394151020250704
# Prediction for 24814 user_id for item_id 85 is 0.33242104017001056
# Prediction for 24814 user_id for item_id 87 is 0.15972160829434268
# Prediction for 24814 user_id for item_id 88 is 0.15160260574989298
# Prediction for 24814 user_id for item_id 89 is 0.3100284250642048
# Prediction for 24814 user_id for item_id 90 is 0.3745799069911509
# Prediction for 24814 user_id for item_id 91 is 0.10495644058440015
# Prediction for 24814 user_id for item_id 92 is 0.12291025476088561
# Prediction for 24814 user_id for item_id 93 is 0.5237028376273076
# Prediction for 24814 user_id for item_id 95 is 0.26219749009254234
# Prediction for 24814 user_id for item_id 96 is 0.3341532043010656
# Prediction for 24814 user_id for item_id 97 is 0.469573071220062
# Prediction for 24814 user_id for item_id 98 is 0.16690552921993929
# Prediction for 24814 user_id for item_id 99 is 0.13550880364724338
# Prediction for 24815 user_id for item_id 70 is 1.4380796979339852
# Prediction for 24815 user_id for item_id 71 is 0.7820376313389114
# Prediction for 24815 user_id for item_id 72 is 0.8876116391793888
# Prediction for 24815 user_id for item_id 73 is 0.9169658691458186
# Prediction for 24815 user_id for item_id 74 is 0.8535055211998491
# Prediction for 24815 user_id for item_id 75 is 1.4422543303926225
# Prediction for 24815 user_id for item_id 76 is 2.599092103199135
# Prediction for 24815 user_id for item_id 77 is 1.8088937033118206
# Prediction for 24815 user_id for item_id 78 is 1.534136681896271
# Prediction for 24815 user_id for item_id 79 is 2.6478481199427204
# Prediction for 24815 user_id for item_id 80 is 1.0306070918865853
# Prediction for 24815 user_id for item_id 81 is 1.0849358112546936
# Prediction for 24815 user_id for item_id 82 is 1.825660619788592
# Prediction for 24815 user_id for item_id 83 is 2.779875438404235
# Prediction for 24815 user_id for item_id 84 is 2.325280159465395
# Prediction for 24815 user_id for item_id 85 is 1.541140208065321
# Prediction for 24815 user_id for item_id 87 is 1.0660280968855054
# Prediction for 24815 user_id for item_id 88 is 0.9989170897505132
# Prediction for 24815 user_id for item_id 89 is 1.818648300727852
# Prediction for 24815 user_id for item_id 90 is 2.056981918531912
# Prediction for 24815 user_id for item_id 91 is 0.6908920743216538
# Prediction for 24815 user_id for item_id 92 is 0.9610826722071792
# Prediction for 24815 user_id for item_id 93 is 2.49522041768552
# Prediction for 24815 user_id for item_id 94 is 1.7310701205182932
# Prediction for 24815 user_id for item_id 95 is 1.0953172725579579
# Prediction for 24815 user_id for item_id 97 is 2.1654802544922966
# Prediction for 24815 user_id for item_id 98 is 1.0819752793317945
# Prediction for 24815 user_id for item_id 99 is 0.9823835164191376
# Prediction for 24816 user_id for item_id 0 is 0.8509374617199371
# Prediction for 24816 user_id for item_id 1 is 1.5228898617384778
# Prediction for 24816 user_id for item_id 2 is 1.493522337505204
# Prediction for 24816 user_id for item_id 3 is 1.116849628009284
# Prediction for 24816 user_id for item_id 8 is 1.2913100260415444
# Prediction for 24816 user_id for item_id 9 is 0.6901731532283779
# Prediction for 24816 user_id for item_id 11 is 1.2188177414027457
# Prediction for 24816 user_id for item_id 21 is 0.8379703292798145
# Prediction for 24816 user_id for item_id 22 is 1.5250420296392058
# Prediction for 24816 user_id for item_id 23 is 1.7967554482254973
# Prediction for 24816 user_id for item_id 24 is 0.817497812210674
# Prediction for 24816 user_id for item_id 29 is 1.0578266490425374
# Prediction for 24816 user_id for item_id 32 is 1.4665712599943206
# Prediction for 24816 user_id for item_id 33 is 1.7222774428607908
# Prediction for 24816 user_id for item_id 36 is 0.9863814053257028
# Prediction for 24816 user_id for item_id 37 is 1.1464295363896586
# Prediction for 24816 user_id for item_id 40 is 0.5071780928997608
# Prediction for 24816 user_id for item_id 42 is 1.1569366869520505
# Prediction for 24816 user_id for item_id 43 is 1.5179868184239724
# Prediction for 24816 user_id for item_id 44 is 1.6674043325795906
# Prediction for 24816 user_id for item_id 45 is 1.2091788380006552
# Prediction for 24816 user_id for item_id 46 is 0.9726288621557079
# Prediction for 24816 user_id for item_id 50 is 1.002835329950504
# Prediction for 24816 user_id for item_id 54 is 0.38137471542048856
# Prediction for 24816 user_id for item_id 57 is 1.5998392798633585
# Prediction for 24816 user_id for item_id 58 is 1.0659239965523102
# Prediction for 24816 user_id for item_id 59 is 1.8509528700648448
# Prediction for 24816 user_id for item_id 62 is 1.4065275544835347
# Prediction for 24816 user_id for item_id 63 is 1.5078965536179212
# Prediction for 24816 user_id for item_id 66 is 1.587381835898121
# Prediction for 24816 user_id for item_id 69 is 0.5655241317525677
# Prediction for 24816 user_id for item_id 70 is 1.0383582455023106
# Prediction for 24816 user_id for item_id 71 is 0.7427173720475709
# Prediction for 24816 user_id for item_id 72 is 0.7972991938565036
# Prediction for 24816 user_id for item_id 73 is 0.8526419734137892
# Prediction for 24816 user_id for item_id 74 is 0.6089850202098056
# Prediction for 24816 user_id for item_id 75 is 0.6964732401762594
# Prediction for 24816 user_id for item_id 76 is 1.962591939791592
# Prediction for 24816 user_id for item_id 77 is 1.1074749493076006
# Prediction for 24816 user_id for item_id 78 is 1.3598879407574402
# Prediction for 24816 user_id for item_id 79 is 1.856117991658527
# Prediction for 24816 user_id for item_id 80 is 0.4998118084251137
# Prediction for 24816 user_id for item_id 81 is 0.5492141983166584
# Prediction for 24816 user_id for item_id 82 is 1.3674632480002005
# Prediction for 24816 user_id for item_id 83 is 1.711204726850224
# Prediction for 24816 user_id for item_id 84 is 1.753969815835464
# Prediction for 24816 user_id for item_id 85 is 1.3457191839835747
# Prediction for 24816 user_id for item_id 86 is 1.204731936658225
# Prediction for 24816 user_id for item_id 87 is 0.40854081219242394
# Prediction for 24816 user_id for item_id 88 is 0.6166625096093316
# Prediction for 24816 user_id for item_id 89 is 1.2990767635210527
# Prediction for 24816 user_id for item_id 90 is 1.4288842507167026
# Prediction for 24816 user_id for item_id 91 is 0.7769261306715802
# Prediction for 24816 user_id for item_id 92 is 0.34770686519538213
# Prediction for 24816 user_id for item_id 93 is 1.4907083512388553
# Prediction for 24816 user_id for item_id 94 is 0.8590111974896488
# Prediction for 24816 user_id for item_id 95 is 1.3027316257249328
# Prediction for 24816 user_id for item_id 97 is 1.6694125810449767
# Prediction for 24816 user_id for item_id 99 is 0.5162305958588449
# Prediction for 24817 user_id for item_id 0 is 0.9258759797400737
# Prediction for 24817 user_id for item_id 2 is 1.3062564823980247
# Prediction for 24817 user_id for item_id 3 is 0.9560284695330857
# Prediction for 24817 user_id for item_id 8 is 1.0114540434967845
# Prediction for 24817 user_id for item_id 23 is 1.7237801879934043
# Prediction for 24817 user_id for item_id 36 is 1.1676675552324782
# Prediction for 24817 user_id for item_id 43 is 1.6478486750453982
# Prediction for 24817 user_id for item_id 56 is 0.9790964365694805
# Prediction for 24817 user_id for item_id 57 is 1.5863563673403256
# Prediction for 24817 user_id for item_id 70 is 1.0765406691149266
# Prediction for 24817 user_id for item_id 71 is 0.855163594422765
# Prediction for 24817 user_id for item_id 73 is 0.6896247129441762
# Prediction for 24817 user_id for item_id 74 is 0.6122178848475653
# Prediction for 24817 user_id for item_id 75 is 0.6372590274211959
# Prediction for 24817 user_id for item_id 76 is 1.977863377699841
# Prediction for 24817 user_id for item_id 77 is 0.8791917024597407
# Prediction for 24817 user_id for item_id 78 is 0.9590666647109338
# Prediction for 24817 user_id for item_id 79 is 1.7083647115720786
# Prediction for 24817 user_id for item_id 80 is 0.47604358994589296
# Prediction for 24817 user_id for item_id 81 is 0.38545955568330814
# Prediction for 24817 user_id for item_id 82 is 1.0256261607449795
# Prediction for 24817 user_id for item_id 84 is 1.2773946430268528
# Prediction for 24817 user_id for item_id 85 is 1.286635096552883
# Prediction for 24817 user_id for item_id 86 is 0.9422495741686625
# Prediction for 24817 user_id for item_id 87 is 0.7217956017331498
# Prediction for 24817 user_id for item_id 88 is 0.8707098632511847
# Prediction for 24817 user_id for item_id 89 is 1.6408977759508874
# Prediction for 24817 user_id for item_id 90 is 1.2725750301321967
# Prediction for 24817 user_id for item_id 91 is 0.8652448923640169
# Prediction for 24817 user_id for item_id 92 is 0.3663609738922614
# Prediction for 24817 user_id for item_id 93 is 1.3600615238436278
# Prediction for 24817 user_id for item_id 94 is 1.1200678923051222
# Prediction for 24817 user_id for item_id 95 is 1.0870084669636544
# Prediction for 24817 user_id for item_id 96 is 1.1733383938280169
# Prediction for 24817 user_id for item_id 97 is 1.5004453607584254
# Prediction for 24817 user_id for item_id 98 is 0.6351160721353817
# Prediction for 24817 user_id for item_id 99 is 0.48235693076793773
# Prediction for 24818 user_id for item_id 0 is 0.6611945123877165
# Prediction for 24818 user_id for item_id 1 is 1.110186716765978
# Prediction for 24818 user_id for item_id 2 is 1.1295951192340195
# Prediction for 24818 user_id for item_id 3 is 0.8249515845488701
# Prediction for 24818 user_id for item_id 5 is 1.4132980206318349
# Prediction for 24818 user_id for item_id 8 is 0.9042564218100505
# Prediction for 24818 user_id for item_id 9 is 0.5620234783107178
# Prediction for 24818 user_id for item_id 10 is 0.7806715037624458
# Prediction for 24818 user_id for item_id 11 is 0.8415460622256676
# Prediction for 24818 user_id for item_id 13 is 0.875868680819482
# Prediction for 24818 user_id for item_id 21 is 0.6472390316157772
# Prediction for 24818 user_id for item_id 22 is 1.1371049715181254
# Prediction for 24818 user_id for item_id 23 is 1.3496060783405412
# Prediction for 24818 user_id for item_id 24 is 0.7255804783683768
# Prediction for 24818 user_id for item_id 25 is 1.1284809295916522
# Prediction for 24818 user_id for item_id 28 is 0.8142195657593024
# Prediction for 24818 user_id for item_id 29 is 0.9559864525706169
# Prediction for 24818 user_id for item_id 30 is 0.8224224565958471
# Prediction for 24818 user_id for item_id 32 is 1.1428498952273516
# Prediction for 24818 user_id for item_id 36 is 0.8361006145177025
# Prediction for 24818 user_id for item_id 37 is 0.8945987713806777
# Prediction for 24818 user_id for item_id 38 is 1.02709690793477
# Prediction for 24818 user_id for item_id 40 is 0.3581542461252247
# Prediction for 24818 user_id for item_id 43 is 1.2904200433988273
# Prediction for 24818 user_id for item_id 44 is 1.2127852638621661
# Prediction for 24818 user_id for item_id 45 is 0.9867709971006307
# Prediction for 24818 user_id for item_id 50 is 0.7838017842552585
# Prediction for 24818 user_id for item_id 51 is 0.3180073454079293
# Prediction for 24818 user_id for item_id 54 is 0.23338270081771428
# Prediction for 24818 user_id for item_id 56 is 0.7484799334246975
# Prediction for 24818 user_id for item_id 58 is 0.8985145088809698
# Prediction for 24818 user_id for item_id 59 is 1.4044739959697659
# Prediction for 24818 user_id for item_id 62 is 1.174770982806809
# Prediction for 24818 user_id for item_id 63 is 1.1399700099326415
# Prediction for 24818 user_id for item_id 66 is 1.1276860090071679
# Prediction for 24818 user_id for item_id 70 is 0.8255831621545974
# Prediction for 24818 user_id for item_id 71 is 0.6727662476748815
# Prediction for 24818 user_id for item_id 72 is 0.677649954918139
# Prediction for 24818 user_id for item_id 73 is 0.6376927700287532
# Prediction for 24818 user_id for item_id 74 is 0.5036362674413376
# Prediction for 24818 user_id for item_id 75 is 0.49167127185168435
# Prediction for 24818 user_id for item_id 76 is 1.5704195887261438
# Prediction for 24818 user_id for item_id 77 is 0.7595328572086297
# Prediction for 24818 user_id for item_id 78 is 0.9413965991822048
# Prediction for 24818 user_id for item_id 79 is 1.3986828049958842
# Prediction for 24818 user_id for item_id 80 is 0.3529672553477457
# Prediction for 24818 user_id for item_id 82 is 0.9478757325928908
# Prediction for 24818 user_id for item_id 83 is 1.285948461281655
# Prediction for 24818 user_id for item_id 84 is 1.2027840478646106
# Prediction for 24818 user_id for item_id 85 is 1.0754398792006186
# Prediction for 24818 user_id for item_id 86 is 0.9048532224235746
# Prediction for 24818 user_id for item_id 87 is 0.39855741968340846
# Prediction for 24818 user_id for item_id 88 is 0.5853524016506055
# Prediction for 24818 user_id for item_id 89 is 1.1782644427365516
# Prediction for 24818 user_id for item_id 90 is 1.0707334347760054
# Prediction for 24818 user_id for item_id 91 is 0.7122206719842007
# Prediction for 24818 user_id for item_id 92 is 0.24256332470653746
# Prediction for 24818 user_id for item_id 93 is 1.0611728634831383
# Prediction for 24818 user_id for item_id 94 is 0.7291665028260835
# Prediction for 24818 user_id for item_id 95 is 1.024597603902384
# Prediction for 24818 user_id for item_id 97 is 1.2602768712568226
# Prediction for 24818 user_id for item_id 98 is 0.4105025168390338
# Prediction for 24818 user_id for item_id 99 is 0.38049920477453697
# Prediction for 24821 user_id for item_id 0 is 0.8311657641988457
# Prediction for 24821 user_id for item_id 2 is 1.3163436935959159
# Prediction for 24821 user_id for item_id 3 is 0.9440182876754522
# Prediction for 24821 user_id for item_id 8 is 1.0192507407893958
# Prediction for 24821 user_id for item_id 23 is 1.6245791373489809
# Prediction for 24821 user_id for item_id 29 is 1.266942491202963
# Prediction for 24821 user_id for item_id 32 is 1.3725889109379477
# Prediction for 24821 user_id for item_id 36 is 1.063610787244714
# Prediction for 24821 user_id for item_id 37 is 1.0798587889125473
# Prediction for 24821 user_id for item_id 40 is 0.48549462634933443
# Prediction for 24821 user_id for item_id 42 is 1.0827890106727587
# Prediction for 24821 user_id for item_id 43 is 1.5957887180278194
# Prediction for 24821 user_id for item_id 54 is 0.2684494233454742
# Prediction for 24821 user_id for item_id 56 is 0.9074519655115464
# Prediction for 24821 user_id for item_id 57 is 1.5116938859832552
# Prediction for 24821 user_id for item_id 58 is 1.1540287958051607
# Prediction for 24821 user_id for item_id 59 is 1.6848244781341493
# Prediction for 24821 user_id for item_id 63 is 1.3427407908027986
# Prediction for 24821 user_id for item_id 66 is 1.292092225450967
# Prediction for 24821 user_id for item_id 69 is 0.4453209696526801
# Prediction for 24821 user_id for item_id 70 is 1.0028645759983796
# Prediction for 24821 user_id for item_id 71 is 0.8467694718537041
# Prediction for 24821 user_id for item_id 72 is 0.8278819703898392
# Prediction for 24821 user_id for item_id 73 is 0.7166817064473844
# Prediction for 24821 user_id for item_id 74 is 0.6226059278253782
# Prediction for 24821 user_id for item_id 75 is 0.5999351918799963
# Prediction for 24821 user_id for item_id 76 is 1.899289812448103
# Prediction for 24821 user_id for item_id 77 is 0.8628645950417473
# Prediction for 24821 user_id for item_id 78 is 1.0063459184425858
# Prediction for 24821 user_id for item_id 79 is 1.6495285279933587
# Prediction for 24821 user_id for item_id 80 is 0.4314636955192315
# Prediction for 24821 user_id for item_id 81 is 0.369733764093477
# Prediction for 24821 user_id for item_id 82 is 1.0431628614145427
# Prediction for 24821 user_id for item_id 83 is 1.5500654172707573
# Prediction for 24821 user_id for item_id 84 is 1.3111198508000683
# Prediction for 24821 user_id for item_id 85 is 1.2741378308667626
# Prediction for 24821 user_id for item_id 86 is 1.0018351458148302
# Prediction for 24821 user_id for item_id 87 is 0.5884278474674377
# Prediction for 24821 user_id for item_id 88 is 0.7915981134508064
# Prediction for 24821 user_id for item_id 89 is 1.5328205811827436
# Prediction for 24821 user_id for item_id 90 is 1.2583160039127226
# Prediction for 24821 user_id for item_id 91 is 0.8877226343515425
# Prediction for 24821 user_id for item_id 92 is 0.3188259745176122
# Prediction for 24821 user_id for item_id 93 is 1.2464110771785135
# Prediction for 24821 user_id for item_id 94 is 0.9740513884402614
# Prediction for 24821 user_id for item_id 95 is 1.159124367348807
# Prediction for 24821 user_id for item_id 96 is 1.1430596237531505
# Prediction for 24821 user_id for item_id 97 is 1.466158598673712
# Prediction for 24821 user_id for item_id 98 is 0.551678884488254
# Prediction for 24821 user_id for item_id 99 is 0.4661254066284449
# Prediction for 24822 user_id for item_id 0 is 1.306613395467031
# Prediction for 24822 user_id for item_id 1 is 1.7035382986727396
# Prediction for 24822 user_id for item_id 2 is 1.9162862020927591
# Prediction for 24822 user_id for item_id 3 is 1.3598027760782179
# Prediction for 24822 user_id for item_id 5 is 2.533522027026842
# Prediction for 24822 user_id for item_id 8 is 1.7180588255492868
# Prediction for 24822 user_id for item_id 9 is 0.9630765195896351
# Prediction for 24822 user_id for item_id 10 is 1.558326777108941
# Prediction for 24822 user_id for item_id 11 is 1.6572238411344506
# Prediction for 24822 user_id for item_id 13 is 1.3611281292617479
# Prediction for 24822 user_id for item_id 21 is 1.5419619941374938
# Prediction for 24822 user_id for item_id 23 is 2.5562057834830965
# Prediction for 24822 user_id for item_id 24 is 1.321684552617939
# Prediction for 24822 user_id for item_id 29 is 1.5962604748714655
# Prediction for 24822 user_id for item_id 32 is 1.9160682231483126
# Prediction for 24822 user_id for item_id 36 is 1.3570882835208373
# Prediction for 24822 user_id for item_id 39 is 1.7669231084171968
# Prediction for 24822 user_id for item_id 40 is 1.0878145946269329
# Prediction for 24822 user_id for item_id 42 is 1.6867794089663137
# Prediction for 24822 user_id for item_id 43 is 1.9057613148430166
# Prediction for 24822 user_id for item_id 50 is 1.5635159470502888
# Prediction for 24822 user_id for item_id 51 is 0.8053759497056397
# Prediction for 24822 user_id for item_id 54 is 0.6441339366983544
# Prediction for 24822 user_id for item_id 56 is 1.517654534874675
# Prediction for 24822 user_id for item_id 57 is 1.97004921220929
# Prediction for 24822 user_id for item_id 58 is 1.6120901743841212
# Prediction for 24822 user_id for item_id 59 is 2.509601505275181
# Prediction for 24822 user_id for item_id 62 is 2.2005666455208996
# Prediction for 24822 user_id for item_id 63 is 2.0131971053566105
# Prediction for 24822 user_id for item_id 66 is 2.084686796961227
# Prediction for 24822 user_id for item_id 69 is 1.0642146536825103
# Prediction for 24822 user_id for item_id 70 is 1.330021079091843
# Prediction for 24822 user_id for item_id 71 is 0.9091315847834496
# Prediction for 24822 user_id for item_id 72 is 0.989291840748638
# Prediction for 24822 user_id for item_id 73 is 0.9623005359131611
# Prediction for 24822 user_id for item_id 75 is 1.1833947368274178
# Prediction for 24822 user_id for item_id 76 is 2.5078597193582017
# Prediction for 24822 user_id for item_id 77 is 1.5624176831286054
# Prediction for 24822 user_id for item_id 78 is 1.5137746492015973
# Prediction for 24822 user_id for item_id 79 is 2.436825267973427
# Prediction for 24822 user_id for item_id 80 is 0.8260824861825358
# Prediction for 24822 user_id for item_id 81 is 0.8591147213232302
# Prediction for 24822 user_id for item_id 82 is 1.6912497302688432
# Prediction for 24822 user_id for item_id 83 is 2.417474690771727
# Prediction for 24822 user_id for item_id 84 is 2.1571083395902835
# Prediction for 24822 user_id for item_id 85 is 1.593216993247517
# Prediction for 24822 user_id for item_id 86 is 1.262825914634713
# Prediction for 24822 user_id for item_id 87 is 0.8365700570158235
# Prediction for 24822 user_id for item_id 88 is 0.9495751469531791
# Prediction for 24822 user_id for item_id 89 is 1.8073746508077213
# Prediction for 24822 user_id for item_id 90 is 1.9182421908561886
# Prediction for 24822 user_id for item_id 91 is 0.904323143655328
# Prediction for 24822 user_id for item_id 92 is 0.7270029374281323
# Prediction for 24822 user_id for item_id 93 is 2.0816920795688874
# Prediction for 24822 user_id for item_id 94 is 1.4368358015389875
# Prediction for 24822 user_id for item_id 95 is 1.3381807578904399
# Prediction for 24822 user_id for item_id 96 is 1.632781730372999
# Prediction for 24822 user_id for item_id 97 is 2.0610966559151125
# Prediction for 24822 user_id for item_id 98 is 0.8796108802018078
# Prediction for 24822 user_id for item_id 99 is 0.8446263860308068
# Prediction for 24823 user_id for item_id 57 is 1.1001522652603009
# Prediction for 24823 user_id for item_id 70 is 0.7694838790956314
# Prediction for 24823 user_id for item_id 71 is 0.37299482117046623
# Prediction for 24823 user_id for item_id 72 is 0.3255837941616608
# Prediction for 24823 user_id for item_id 73 is 0.4100982030547054
# Prediction for 24823 user_id for item_id 74 is 0.16145669908583382
# Prediction for 24823 user_id for item_id 75 is 0.26269000862790814
# Prediction for 24823 user_id for item_id 76 is 1.2161609093143813
# Prediction for 24823 user_id for item_id 77 is 0.5150764983972145
# Prediction for 24823 user_id for item_id 78 is 0.6888832341714898
# Prediction for 24823 user_id for item_id 79 is 1.0762030015106143
# Prediction for 24823 user_id for item_id 80 is 0.27701011651275464
# Prediction for 24823 user_id for item_id 81 is 0.2359945941527119
# Prediction for 24823 user_id for item_id 82 is 0.6743680973879648
# Prediction for 24823 user_id for item_id 83 is 1.0892944509211853
# Prediction for 24823 user_id for item_id 84 is 0.8364610432698657
# Prediction for 24823 user_id for item_id 85 is 0.7733499887247601
# Prediction for 24823 user_id for item_id 86 is 0.5715370455959838
# Prediction for 24823 user_id for item_id 87 is 0.4282143588257028
# Prediction for 24823 user_id for item_id 88 is 0.4248130321993269
# Prediction for 24823 user_id for item_id 89 is 0.8444061948049327
# Prediction for 24823 user_id for item_id 90 is 0.675217238845552
# Prediction for 24823 user_id for item_id 91 is 0.30096020455651984
# Prediction for 24823 user_id for item_id 92 is 0.1366868847309819
# Prediction for 24823 user_id for item_id 93 is 1.0533470834625678
# Prediction for 24823 user_id for item_id 94 is 0.6798708737748044
# Prediction for 24823 user_id for item_id 95 is 0.5889757088132588
# Prediction for 24823 user_id for item_id 97 is 0.9985633976587569
# Prediction for 24823 user_id for item_id 98 is 0.3500051301926768
# Prediction for 24823 user_id for item_id 99 is 0.16861856332742167
# Prediction for 24825 user_id for item_id 0 is 0.9856991762810996
# Prediction for 24825 user_id for item_id 1 is 0.8825436093671164
# Prediction for 24825 user_id for item_id 2 is 1.2074039301987451
# Prediction for 24825 user_id for item_id 3 is 0.7982816129761423
# Prediction for 24825 user_id for item_id 8 is 1.0727329829323358
# Prediction for 24825 user_id for item_id 23 is 1.779191639780286
# Prediction for 24825 user_id for item_id 36 is 0.9885131978194105
# Prediction for 24825 user_id for item_id 42 is 1.2085941673803386
# Prediction for 24825 user_id for item_id 43 is 1.278094413561723
# Prediction for 24825 user_id for item_id 56 is 1.0935107895670468
# Prediction for 24825 user_id for item_id 57 is 1.234484225087525
# Prediction for 24825 user_id for item_id 59 is 1.6862451730306907
# Prediction for 24825 user_id for item_id 70 is 0.8733899555072708
# Prediction for 24825 user_id for item_id 71 is 0.6218701503226822
# Prediction for 24825 user_id for item_id 72 is 0.651698118081911
# Prediction for 24825 user_id for item_id 74 is 0.6310885703942467
# Prediction for 24825 user_id for item_id 75 is 0.9137325691733289
# Prediction for 24825 user_id for item_id 77 is 1.0252694084211922
# Prediction for 24825 user_id for item_id 78 is 0.7406344580302324
# Prediction for 24825 user_id for item_id 79 is 1.5758708557488919
# Prediction for 24825 user_id for item_id 80 is 0.6283229726546772
# Prediction for 24825 user_id for item_id 81 is 0.5892766059369807
# Prediction for 24825 user_id for item_id 82 is 0.9647918205989864
# Prediction for 24825 user_id for item_id 83 is 1.6753720218183064
# Prediction for 24825 user_id for item_id 85 is 0.9595070546186225
# Prediction for 24825 user_id for item_id 86 is 0.6026280464742542
# Prediction for 24825 user_id for item_id 87 is 0.8058396530634502
# Prediction for 24825 user_id for item_id 88 is 0.7914734172943955
# Prediction for 24825 user_id for item_id 89 is 1.3767815575624691
# Prediction for 24825 user_id for item_id 90 is 1.2594384549982403
# Prediction for 24825 user_id for item_id 91 is 0.5930982863472256
# Prediction for 24825 user_id for item_id 92 is 0.6313512795010204
# Prediction for 24825 user_id for item_id 93 is 1.3898965897324196
# Prediction for 24825 user_id for item_id 94 is 1.193374795676018
# Prediction for 24825 user_id for item_id 95 is 0.6473317530755132
# Prediction for 24825 user_id for item_id 96 is 1.0664091822484758
# Prediction for 24825 user_id for item_id 97 is 1.2500891488466026
# Prediction for 24825 user_id for item_id 98 is 0.7482639081083123
# Prediction for 24825 user_id for item_id 99 is 0.645419936103809
# Prediction for 24826 user_id for item_id 0 is 0.7333828346292967
# Prediction for 24826 user_id for item_id 1 is 1.094111720529667
# Prediction for 24826 user_id for item_id 2 is 0.9261997621788033
# Prediction for 24826 user_id for item_id 3 is 0.8138913911624025
# Prediction for 24826 user_id for item_id 5 is 1.3366398095140375
# Prediction for 24826 user_id for item_id 8 is 0.8511842951023348
# Prediction for 24826 user_id for item_id 9 is 0.43877681084953435
# Prediction for 24826 user_id for item_id 10 is 1.0181636694006901
# Prediction for 24826 user_id for item_id 11 is 1.107563270002695
# Prediction for 24826 user_id for item_id 13 is 0.6094036415260622
# Prediction for 24826 user_id for item_id 21 is 0.8308405563186568
# Prediction for 24826 user_id for item_id 22 is 1.1324958423812785
# Prediction for 24826 user_id for item_id 23 is 1.3667639963221425
# Prediction for 24826 user_id for item_id 24 is 0.6479534424170279
# Prediction for 24826 user_id for item_id 25 is 0.8167403640468915
# Prediction for 24826 user_id for item_id 29 is 0.8104794426564684
# Prediction for 24826 user_id for item_id 32 is 1.1065846953920164
# Prediction for 24826 user_id for item_id 33 is 1.1319911849580193
# Prediction for 24826 user_id for item_id 36 is 0.8341474143580659
# Prediction for 24826 user_id for item_id 38 is 0.8750107312665363
# Prediction for 24826 user_id for item_id 39 is 1.0269973662288037
# Prediction for 24826 user_id for item_id 40 is 0.5066043821421848
# Prediction for 24826 user_id for item_id 42 is 0.7091251669788241
# Prediction for 24826 user_id for item_id 43 is 1.0144590031353773
# Prediction for 24826 user_id for item_id 44 is 1.0026076551675858
# Prediction for 24826 user_id for item_id 46 is 0.8363513924233187
# Prediction for 24826 user_id for item_id 50 is 0.7480595805563721
# Prediction for 24826 user_id for item_id 51 is 0.3556332278632493
# Prediction for 24826 user_id for item_id 54 is 0.3481784236004828
# Prediction for 24826 user_id for item_id 57 is 1.256007349581637
# Prediction for 24826 user_id for item_id 58 is 0.7427107654534759
# Prediction for 24826 user_id for item_id 62 is 0.9448387135891937
# Prediction for 24826 user_id for item_id 63 is 0.9600892376224467
# Prediction for 24826 user_id for item_id 66 is 1.2652070026011266
# Prediction for 24826 user_id for item_id 69 is 0.45510338598445527
# Prediction for 24826 user_id for item_id 71 is 0.4074493004271648
# Prediction for 24826 user_id for item_id 72 is 0.4081087052803518
# Prediction for 24826 user_id for item_id 73 is 0.5311475332388883
# Prediction for 24826 user_id for item_id 74 is 0.26865863828390363
# Prediction for 24826 user_id for item_id 75 is 0.4652037704202842
# Prediction for 24826 user_id for item_id 76 is 1.4317564552318174
# Prediction for 24826 user_id for item_id 77 is 0.7790243194679821
# Prediction for 24826 user_id for item_id 78 is 0.9247981386684893
# Prediction for 24826 user_id for item_id 79 is 1.3638530147029497
# Prediction for 24826 user_id for item_id 80 is 0.40353121016260274
# Prediction for 24826 user_id for item_id 81 is 0.413243572920252
# Prediction for 24826 user_id for item_id 82 is 0.9441898530763514
# Prediction for 24826 user_id for item_id 83 is 1.3717273607631422
# Prediction for 24826 user_id for item_id 85 is 0.9093370017541839
# Prediction for 24826 user_id for item_id 86 is 0.7237878663902301
# Prediction for 24826 user_id for item_id 87 is 0.4513453310199657
# Prediction for 24826 user_id for item_id 88 is 0.451022226387812
# Prediction for 24826 user_id for item_id 89 is 0.9111359106653659
# Prediction for 24826 user_id for item_id 90 is 0.9336334099059447
# Prediction for 24826 user_id for item_id 91 is 0.33740912749059887
# Prediction for 24826 user_id for item_id 92 is 0.2634025005733424
# Prediction for 24826 user_id for item_id 93 is 1.3187252787033399
# Prediction for 24826 user_id for item_id 94 is 0.7820953181386836
# Prediction for 24826 user_id for item_id 95 is 0.7215357816140738
# Prediction for 24826 user_id for item_id 96 is 0.8656077741491455
# Prediction for 24826 user_id for item_id 97 is 1.2271513854863187
# Prediction for 24826 user_id for item_id 98 is 0.43122194715665263
# Prediction for 24826 user_id for item_id 99 is 0.30604099071144375
# Prediction for 24827 user_id for item_id 0 is 1.3501110950282293
# Prediction for 24827 user_id for item_id 1 is 1.5522567193418009
# Prediction for 24827 user_id for item_id 2 is 1.8423412499464036
# Prediction for 24827 user_id for item_id 3 is 1.2931894903043182
# Prediction for 24827 user_id for item_id 8 is 1.817872411835059
# Prediction for 24827 user_id for item_id 9 is 0.9016142201829757
# Prediction for 24827 user_id for item_id 23 is 2.620493137895859
# Prediction for 24827 user_id for item_id 29 is 1.3969608204586799
# Prediction for 24827 user_id for item_id 32 is 1.7959190798573599
# Prediction for 24827 user_id for item_id 36 is 1.1915945376796195
# Prediction for 24827 user_id for item_id 42 is 1.7176066399033383
# Prediction for 24827 user_id for item_id 43 is 1.5480558970023683
# Prediction for 24827 user_id for item_id 50 is 1.6244409944951534
# Prediction for 24827 user_id for item_id 54 is 0.8099536838595441
# Prediction for 24827 user_id for item_id 56 is 1.6197944887987217
# Prediction for 24827 user_id for item_id 57 is 1.7369618640424924
# Prediction for 24827 user_id for item_id 63 is 1.9840586066101888
# Prediction for 24827 user_id for item_id 66 is 2.154801552909425
# Prediction for 24827 user_id for item_id 69 is 1.3429731884939409
# Prediction for 24827 user_id for item_id 71 is 0.6494282592708284
# Prediction for 24827 user_id for item_id 72 is 0.7993228262961382
# Prediction for 24827 user_id for item_id 73 is 0.856508917338875
# Prediction for 24827 user_id for item_id 74 is 0.814157479606443
# Prediction for 24827 user_id for item_id 75 is 1.3788485584855528
# Prediction for 24827 user_id for item_id 76 is 2.242490574488847
# Prediction for 24827 user_id for item_id 77 is 1.7265862382927812
# Prediction for 24827 user_id for item_id 78 is 1.4659803676191672
# Prediction for 24827 user_id for item_id 79 is 2.3786512731821543
# Prediction for 24827 user_id for item_id 80 is 0.9501868382482405
# Prediction for 24827 user_id for item_id 81 is 1.0610959955157893
# Prediction for 24827 user_id for item_id 83 is 2.465238337333344
# Prediction for 24827 user_id for item_id 84 is 2.2346532025233103
# Prediction for 24827 user_id for item_id 85 is 1.3429979255677804
# Prediction for 24827 user_id for item_id 86 is 1.0512405107937433
# Prediction for 24827 user_id for item_id 87 is 0.8296080730096708
# Prediction for 24827 user_id for item_id 89 is 1.469278255062721
# Prediction for 24827 user_id for item_id 90 is 1.912956383713733
# Prediction for 24827 user_id for item_id 91 is 0.5935481685993973
# Prediction for 24827 user_id for item_id 92 is 0.9076857638853302
# Prediction for 24827 user_id for item_id 93 is 2.2108890816395164
# Prediction for 24827 user_id for item_id 94 is 1.4367889310289808
# Prediction for 24827 user_id for item_id 95 is 1.01282659559549
# Prediction for 24827 user_id for item_id 96 is 1.554747559184029
# Prediction for 24827 user_id for item_id 97 is 1.9288820374191795
# Prediction for 24827 user_id for item_id 98 is 0.9270151191561875
# Prediction for 24827 user_id for item_id 99 is 0.943163218509376
# Prediction for 24828 user_id for item_id 0 is 0.7107657824144454
# Prediction for 24828 user_id for item_id 1 is 1.2163929842705665
# Prediction for 24828 user_id for item_id 2 is 1.1892311188813633
# Prediction for 24828 user_id for item_id 3 is 0.902690579728125
# Prediction for 24828 user_id for item_id 5 is 1.4663696629732297
# Prediction for 24828 user_id for item_id 8 is 1.1246479752570355
# Prediction for 24828 user_id for item_id 9 is 0.5205015074844287
# Prediction for 24828 user_id for item_id 10 is 1.165141124563748
# Prediction for 24828 user_id for item_id 11 is 1.096741965365411
# Prediction for 24828 user_id for item_id 13 is 0.8360085016585879
# Prediction for 24828 user_id for item_id 21 is 0.760861504208236
# Prediction for 24828 user_id for item_id 22 is 1.28034049641709
# Prediction for 24828 user_id for item_id 23 is 1.50377730238969
# Prediction for 24828 user_id for item_id 24 is 0.5914996807188695
# Prediction for 24828 user_id for item_id 25 is 1.100098656374494
# Prediction for 24828 user_id for item_id 29 is 0.7218296904930288
# Prediction for 24828 user_id for item_id 32 is 1.1461736394105395
# Prediction for 24828 user_id for item_id 36 is 0.7128427436593971
# Prediction for 24828 user_id for item_id 38 is 1.1671283111973751
# Prediction for 24828 user_id for item_id 39 is 1.0163992929134582
# Prediction for 24828 user_id for item_id 40 is 0.5296703504498431
# Prediction for 24828 user_id for item_id 44 is 1.371461884814385
# Prediction for 24828 user_id for item_id 46 is 0.8263533830430174
# Prediction for 24828 user_id for item_id 50 is 0.8316593879434444
# Prediction for 24828 user_id for item_id 51 is 0.4642761289667717
# Prediction for 24828 user_id for item_id 54 is 0.40229942613380676
# Prediction for 24828 user_id for item_id 57 is 1.2092945874092424
# Prediction for 24828 user_id for item_id 58 is 0.7976470373453153
# Prediction for 24828 user_id for item_id 59 is 1.5126099700428917
# Prediction for 24828 user_id for item_id 63 is 1.2182168549700205
# Prediction for 24828 user_id for item_id 66 is 1.3693442421775093
# Prediction for 24828 user_id for item_id 69 is 0.5950797207888043
# Prediction for 24828 user_id for item_id 70 is 0.7916355380892733
# Prediction for 24828 user_id for item_id 71 is 0.4547430313229705
# Prediction for 24828 user_id for item_id 72 is 0.5397238692804083
# Prediction for 24828 user_id for item_id 73 is 0.6606600825563642
# Prediction for 24828 user_id for item_id 74 is 0.44846573021180075
# Prediction for 24828 user_id for item_id 75 is 0.6540509146461937
# Prediction for 24828 user_id for item_id 77 is 1.0028245346390066
# Prediction for 24828 user_id for item_id 78 is 1.138579880793934
# Prediction for 24828 user_id for item_id 79 is 1.5050949749949776
# Prediction for 24828 user_id for item_id 80 is 0.4679073512125934
# Prediction for 24828 user_id for item_id 81 is 0.5611960275098973
# Prediction for 24828 user_id for item_id 82 is 1.1782103439630558
# Prediction for 24828 user_id for item_id 83 is 1.4314320532874478
# Prediction for 24828 user_id for item_id 84 is 1.5226374464919534
# Prediction for 24828 user_id for item_id 85 is 0.9832559326593691
# Prediction for 24828 user_id for item_id 86 is 0.9083908224094166
# Prediction for 24828 user_id for item_id 88 is 0.3919291229958977
# Prediction for 24828 user_id for item_id 89 is 0.8468559364319288
# Prediction for 24828 user_id for item_id 90 is 1.1683701594022986
# Prediction for 24828 user_id for item_id 91 is 0.45248511394360785
# Prediction for 24828 user_id for item_id 92 is 0.3586870762342666
# Prediction for 24828 user_id for item_id 93 is 1.314701106475706
# Prediction for 24828 user_id for item_id 94 is 0.6735848209201223
# Prediction for 24828 user_id for item_id 95 is 0.9217824556868995
# Prediction for 24828 user_id for item_id 96 is 0.984031011369582
# Prediction for 24828 user_id for item_id 97 is 1.324872782833131
# Prediction for 24828 user_id for item_id 98 is 0.40712598734790933
# Prediction for 24828 user_id for item_id 99 is 0.45825481417247693
# Prediction for 24830 user_id for item_id 8 is 0.908689156562535
# Prediction for 24830 user_id for item_id 23 is 1.3840897478341625
# Prediction for 24830 user_id for item_id 36 is 0.6942485377371095
# Prediction for 24830 user_id for item_id 43 is 0.8859850763278356
# Prediction for 24830 user_id for item_id 56 is 0.8507094692876842
# Prediction for 24830 user_id for item_id 57 is 0.9640897928715019
# Prediction for 24830 user_id for item_id 66 is 1.1150847254018248
# Prediction for 24830 user_id for item_id 70 is 0.6715407584169175
# Prediction for 24830 user_id for item_id 71 is 0.38709570719403663
# Prediction for 24830 user_id for item_id 73 is 0.44034186492258925
# Prediction for 24830 user_id for item_id 74 is 0.427839055842813
# Prediction for 24830 user_id for item_id 75 is 0.6974117908192089
# Prediction for 24830 user_id for item_id 76 is 1.2351648060883962
# Prediction for 24830 user_id for item_id 78 is 0.7252001662462885
# Prediction for 24830 user_id for item_id 79 is 1.2569037941391712
# Prediction for 24830 user_id for item_id 80 is 0.4901453944156499
# Prediction for 24830 user_id for item_id 81 is 0.5162898221120893
# Prediction for 24830 user_id for item_id 82 is 0.8675236343379403
# Prediction for 24830 user_id for item_id 83 is 1.3126777732956325
# Prediction for 24830 user_id for item_id 84 is 1.106026031063825
# Prediction for 24830 user_id for item_id 85 is 0.7362059746154356
# Prediction for 24830 user_id for item_id 86 is 0.5388667412995273
# Prediction for 24830 user_id for item_id 87 is 0.5019307680891134
# Prediction for 24830 user_id for item_id 88 is 0.482231291624
# Prediction for 24830 user_id for item_id 89 is 0.8767279438823832
# Prediction for 24830 user_id for item_id 90 is 0.9901544371619296
# Prediction for 24830 user_id for item_id 91 is 0.35285244467278926
# Prediction for 24830 user_id for item_id 92 is 0.4635620729775163
# Prediction for 24830 user_id for item_id 93 is 1.1627084728564507
# Prediction for 24830 user_id for item_id 94 is 0.8176890139537953
# Prediction for 24830 user_id for item_id 95 is 0.5344881956443647
# Prediction for 24830 user_id for item_id 96 is 0.8260941268787053
# Prediction for 24830 user_id for item_id 97 is 1.0237229048185021
# Prediction for 24830 user_id for item_id 98 is 0.5147598683993146
# Prediction for 24830 user_id for item_id 99 is 0.47937411948955905
# Prediction for 24831 user_id for item_id 70 is 0.5514424202865369
# Prediction for 24831 user_id for item_id 71 is 0.2467271516050542
# Prediction for 24831 user_id for item_id 72 is 0.2183272871063104
# Prediction for 24831 user_id for item_id 73 is 0.1661951484964703
# Prediction for 24831 user_id for item_id 74 is 0.21395499054922723
# Prediction for 24831 user_id for item_id 75 is 0.46953999498732174
# Prediction for 24831 user_id for item_id 76 is 0.8748546084622872
# Prediction for 24831 user_id for item_id 77 is 0.49682300746654784
# Prediction for 24831 user_id for item_id 78 is 0.2543394321324164
# Prediction for 24831 user_id for item_id 79 is 0.8242049794088994
# Prediction for 24831 user_id for item_id 80 is 0.37501813848558047
# Prediction for 24831 user_id for item_id 81 is 0.30801359824605024
# Prediction for 24831 user_id for item_id 82 is 0.40880259653064216
# Prediction for 24831 user_id for item_id 83 is 0.9930339289728081
# Prediction for 24831 user_id for item_id 84 is 0.49047380860522233
# Prediction for 24831 user_id for item_id 85 is 0.4344218805823414
# Prediction for 24831 user_id for item_id 86 is 0.1353486395890638
# Prediction for 24831 user_id for item_id 87 is 0.6232419011318958
# Prediction for 24831 user_id for item_id 89 is 0.7760804371297887
# Prediction for 24831 user_id for item_id 90 is 0.5696549791409392
# Prediction for 24831 user_id for item_id 91 is 0.1527935796031171
# Prediction for 24831 user_id for item_id 92 is 0.37095060242173344
# Prediction for 24831 user_id for item_id 93 is 0.9019681244603132
# Prediction for 24831 user_id for item_id 94 is 0.8237618999013309
# Prediction for 24831 user_id for item_id 95 is 0.10821560240822356
# Prediction for 24831 user_id for item_id 96 is 0.5242568006137803
# Prediction for 24831 user_id for item_id 97 is 0.6349221956919461
# Prediction for 24831 user_id for item_id 98 is 0.49618738298983206
# Prediction for 24831 user_id for item_id 99 is 0.30130113937973824
# Prediction for 24832 user_id for item_id 70 is 0.37823604790436605
# Prediction for 24832 user_id for item_id 71 is 0.4006761699528704
# Prediction for 24832 user_id for item_id 72 is 0.5221791329049242
# Prediction for 24832 user_id for item_id 73 is 0.4295012183730791
# Prediction for 24832 user_id for item_id 74 is 0.5809794220847727
# Prediction for 24832 user_id for item_id 75 is 0.7575081195498163
# Prediction for 24832 user_id for item_id 76 is 0.9460814464497097
# Prediction for 24832 user_id for item_id 77 is 0.8450574405907955
# Prediction for 24832 user_id for item_id 78 is 0.6435872409065152
# Prediction for 24832 user_id for item_id 79 is 1.0349104691588054
# Prediction for 24832 user_id for item_id 80 is 0.4360784072932449
# Prediction for 24832 user_id for item_id 81 is 0.5143057302234256
# Prediction for 24832 user_id for item_id 82 is 0.8058684490238276
# Prediction for 24832 user_id for item_id 83 is 0.999875050680666
# Prediction for 24832 user_id for item_id 84 is 1.05381386753352
# Prediction for 24832 user_id for item_id 85 is 0.6042031098670133
# Prediction for 24832 user_id for item_id 86 is 0.5336665436265353
# Prediction for 24832 user_id for item_id 87 is 0.27371286200984973
# Prediction for 24832 user_id for item_id 88 is 0.37599226218225396
# Prediction for 24832 user_id for item_id 89 is 0.6897444579828655
# Prediction for 24832 user_id for item_id 90 is 0.9855978808393446
# Prediction for 24832 user_id for item_id 92 is 0.4863261148791337
# Prediction for 24832 user_id for item_id 93 is 0.7551155519895939
# Prediction for 24832 user_id for item_id 94 is 0.5430130461740367
# Prediction for 24832 user_id for item_id 95 is 0.5767315603269092
# Prediction for 24832 user_id for item_id 96 is 0.7306893431522635
# Prediction for 24832 user_id for item_id 97 is 0.7913421902557525
# Prediction for 24832 user_id for item_id 98 is 0.3987269092734698
# Prediction for 24832 user_id for item_id 99 is 0.5581666346566535
# Prediction for 24833 user_id for item_id 70 is 0.9220343102170414
# Prediction for 24833 user_id for item_id 71 is 0.5704503647016196
# Prediction for 24833 user_id for item_id 72 is 0.5077412822399923
# Prediction for 24833 user_id for item_id 73 is 0.43185168754741515
# Prediction for 24833 user_id for item_id 74 is 0.37560494297023383
# ...
# Prediction for 24976 user_id for item_id 74 is 0.7536733807503991
# Prediction for 24976 user_id for item_id 75 is 1.0646555941014664
# Prediction for 24976 user_id for item_id 76 is 2.3937826370602813
# Prediction for 24976 user_id for item_id 78 is 1.2560738332999748
# Prediction for 24976 user_id for item_id 79 is 2.2548789615312006
# Prediction for 24976 user_id for item_id 80 is 0.7785016625158807
# Prediction for 24976 user_id for item_id 81 is 0.7410864190888005
# Prediction for 24976 user_id for item_id 82 is 1.4447412269719488
# Prediction for 24976 user_id for item_id 83 is 2.3125674315031737
# Prediction for 24976 user_id for item_id 84 is 1.8192312790433136
# Prediction for 24976 user_id for item_id 85 is 1.471446516554505
# Prediction for 24976 user_id for item_id 86 is 1.046890491427883
# Prediction for 24976 user_id for item_id 87 is 0.9702696009982296
# Prediction for 24976 user_id for item_id 88 is 1.0037359579323406
# Prediction for 24976 user_id for item_id 89 is 1.8447381199718054
# Prediction for 24976 user_id for item_id 90 is 1.7100482189712456
# Prediction for 24976 user_id for item_id 91 is 0.8166378183848634
# Prediction for 24976 user_id for item_id 92 is 0.684999686981172
# Prediction for 24977 user_id for item_id 0 is 0.8481079124662636
# Prediction for 24977 user_id for item_id 1 is 1.1399610169984926
# Prediction for 24977 user_id for item_id 2 is 0.8929222252834477
# Prediction for 24977 user_id for item_id 3 is 0.8560384665756375
# Prediction for 24977 user_id for item_id 5 is 1.4439858325661905
# Prediction for 24977 user_id for item_id 8 is 0.7822823321917419
# Prediction for 24977 user_id for item_id 9 is 0.4616946405370301
# Prediction for 24977 user_id for item_id 11 is 1.2278542805163366
# Prediction for 24977 user_id for item_id 13 is 0.5649692361847428
# Prediction for 24977 user_id for item_id 21 is 0.9902841401991525
# Prediction for 24977 user_id for item_id 22 is 1.1897441129883566
# Prediction for 24977 user_id for item_id 23 is 1.4628100019637627
# Prediction for 24977 user_id for item_id 24 is 0.8005510726612445
# Prediction for 24977 user_id for item_id 25 is 0.7760129483591932
# Prediction for 24977 user_id for item_id 27 is 0.7431394954223536
# Prediction for 24977 user_id for item_id 29 is 1.0151229076649881
# Prediction for 24977 user_id for item_id 32 is 1.2319921652913504
# Prediction for 24977 user_id for item_id 33 is 1.2220441461287712
# Prediction for 24977 user_id for item_id 36 is 1.0352386307402686
# Prediction for 24977 user_id for item_id 37 is 1.1860653015022085
# Prediction for 24977 user_id for item_id 38 is 0.801417047010788
# Prediction for 24977 user_id for item_id 39 is 1.153543099333032
# Prediction for 24977 user_id for item_id 40 is 0.561167163915816
# Prediction for 24977 user_id for item_id 42 is 0.6766085553229314
# Prediction for 24977 user_id for item_id 44 is 0.9031927977864891
# Prediction for 24977 user_id for item_id 46 is 0.945639589085643
# Prediction for 24977 user_id for item_id 50 is 0.8093678143517758
# Prediction for 24977 user_id for item_id 51 is 0.3322213010075446
# Prediction for 24977 user_id for item_id 54 is 0.34831019338580177
# Prediction for 24977 user_id for item_id 56 is 0.8529325020629663
# Prediction for 24977 user_id for item_id 57 is 1.450831391079659
# Prediction for 24977 user_id for item_id 58 is 0.8391495474015946
# Prediction for 24977 user_id for item_id 59 is 1.6800606340580915
# Prediction for 24977 user_id for item_id 62 is 1.0327212936926888
# Prediction for 24977 user_id for item_id 63 is 0.9359077973965513
# Prediction for 24977 user_id for item_id 66 is 1.341475906437006
# Prediction for 24977 user_id for item_id 69 is 0.4231927801037475
# Prediction for 24977 user_id for item_id 71 is 0.46411929739455915
# Prediction for 24977 user_id for item_id 72 is 0.4067123108851926
# Prediction for 24977 user_id for item_id 74 is 0.2169377398213756
# Prediction for 24977 user_id for item_id 75 is 0.4145099396025916
# Prediction for 24977 user_id for item_id 76 is 1.6106403026303384
# Prediction for 24977 user_id for item_id 77 is 0.7296742779681309
# Prediction for 24977 user_id for item_id 78 is 0.8851100200156214
# Prediction for 24977 user_id for item_id 79 is 1.4526460836738402
# Prediction for 24977 user_id for item_id 80 is 0.41490003809453835
# Prediction for 24977 user_id for item_id 81 is 0.3613980547292709
# Prediction for 24977 user_id for item_id 83 is 1.5111190893252104
# Prediction for 24977 user_id for item_id 84 is 1.1159804585022994
# Prediction for 24977 user_id for item_id 85 is 0.9936828035935904
# Prediction for 24977 user_id for item_id 86 is 0.6991334174284566
# Prediction for 24977 user_id for item_id 87 is 0.6304996400314974
# Prediction for 24977 user_id for item_id 88 is 0.5810695799700742
# Prediction for 24977 user_id for item_id 89 is 1.123899101625778
# Prediction for 24977 user_id for item_id 90 is 0.916551915464747
# Prediction for 24977 user_id for item_id 91 is 0.35026916429214383
# Prediction for 24977 user_id for item_id 92 is 0.24452252188505716
# Prediction for 24977 user_id for item_id 93 is 1.4677654492580223
# Prediction for 24977 user_id for item_id 94 is 0.9735812777020123
# Prediction for 24977 user_id for item_id 95 is 0.7004499574470261
# Prediction for 24977 user_id for item_id 96 is 0.9122730607523701
# Prediction for 24977 user_id for item_id 97 is 1.3203005175289118
# Prediction for 24977 user_id for item_id 98 is 0.5164832690035641
# Prediction for 24977 user_id for item_id 99 is 0.26084452432766814
# Prediction for 24979 user_id for item_id 70 is 1.3518738404418618
# Prediction for 24979 user_id for item_id 71 is 0.9322725962709413
# Prediction for 24979 user_id for item_id 72 is 0.8876167413187332
# Prediction for 24979 user_id for item_id 73 is 0.8607105008290711
# Prediction for 24979 user_id for item_id 74 is 0.6167923286505989
# Prediction for 24979 user_id for item_id 76 is 2.3860301918697426
# Prediction for 24979 user_id for item_id 77 is 1.0793766480878468
# Prediction for 24979 user_id for item_id 78 is 1.2944224519349632
# Prediction for 24979 user_id for item_id 79 is 2.099282650801827
# Prediction for 24980 user_id for item_id 0 is 0.45435553592639977
# Prediction for 24980 user_id for item_id 1 is 0.9238080245106728
# Prediction for 24980 user_id for item_id 2 is 1.0587026230271923
# Prediction for 24980 user_id for item_id 3 is 0.6815198146821706
# Prediction for 24980 user_id for item_id 5 is 1.1399371102124523
# Prediction for 24980 user_id for item_id 8 is 0.8999464180407694
# Prediction for 24980 user_id for item_id 9 is 0.4813832421647691
# Prediction for 24980 user_id for item_id 10 is 0.6958761650717343
# Prediction for 24980 user_id for item_id 11 is 0.596521897840538
# Prediction for 24980 user_id for item_id 21 is 0.39361231338348746
# Prediction for 24980 user_id for item_id 22 is 0.9537720429059773
# Prediction for 24980 user_id for item_id 23 is 1.0969410019180528
# Prediction for 24980 user_id for item_id 24 is 0.4719024413226123
# Prediction for 24980 user_id for item_id 29 is 0.6130539022811732
# Prediction for 24980 user_id for item_id 32 is 0.8667667439357556
# Prediction for 24980 user_id for item_id 33 is 1.1487085472048963
# Prediction for 24980 user_id for item_id 36 is 0.4986915326129881
# Prediction for 24980 user_id for item_id 38 is 1.011696582456883
# Prediction for 24980 user_id for item_id 39 is 0.5310704892364538
# Prediction for 24980 user_id for item_id 42 is 0.8535792537755624
# Prediction for 24980 user_id for item_id 43 is 0.9702792252550606
# Prediction for 24980 user_id for item_id 44 is 1.214462942084287
# Prediction for 24980 user_id for item_id 51 is 0.32184773276429574
# Prediction for 24980 user_id for item_id 54 is 0.21192785008849882
# Prediction for 24980 user_id for item_id 56 is 0.6094777351279816
# Prediction for 24980 user_id for item_id 57 is 0.8810267663690964
# Prediction for 24980 user_id for item_id 58 is 0.6985319880951931
# Prediction for 24980 user_id for item_id 59 is 1.030107088877477
# Prediction for 24980 user_id for item_id 62 is 0.965847321023672
# Prediction for 24980 user_id for item_id 63 is 1.059402553748001
# Prediction for 24980 user_id for item_id 66 is 0.9099636958189349
# Prediction for 24980 user_id for item_id 69 is 0.37863028333234955
# Prediction for 24980 user_id for item_id 70 is 0.5336348580586007
# Prediction for 24980 user_id for item_id 72 is 0.6150595236509425
# Prediction for 24980 user_id for item_id 73 is 0.5843294812740532
# Prediction for 24980 user_id for item_id 74 is 0.5272884027621835
# Prediction for 24980 user_id for item_id 75 is 0.5178683562374242
# Prediction for 24980 user_id for item_id 76 is 1.1830527574459297
# Prediction for 24980 user_id for item_id 77 is 0.7472498256996144
# Prediction for 24980 user_id for item_id 78 is 0.8815276466277403
# Prediction for 24980 user_id for item_id 79 is 1.142565168008666
# Prediction for 24980 user_id for item_id 80 is 0.3082328619893646
# Prediction for 24980 user_id for item_id 81 is 0.37057982624620944
# Prediction for 24980 user_id for item_id 82 is 0.8993974739966062
# Prediction for 24980 user_id for item_id 83 is 0.9818048238917971
# Prediction for 24980 user_id for item_id 84 is 1.1697409151469893
# Prediction for 24980 user_id for item_id 85 is 0.8546867220944975
# Prediction for 24980 user_id for item_id 86 is 0.832954267393878
# Prediction for 24980 user_id for item_id 87 is 0.14356495856132925
# Prediction for 24980 user_id for item_id 88 is 0.3714603385329665
# Prediction for 24980 user_id for item_id 89 is 0.8010262947120796
# Prediction for 24980 user_id for item_id 90 is 0.9874324716388211
# Prediction for 24980 user_id for item_id 91 is 0.6287654436215707
# Prediction for 24980 user_id for item_id 92 is 0.25307389213216835
# Prediction for 24980 user_id for item_id 93 is 0.7605047220196756
# Prediction for 24980 user_id for item_id 94 is 0.4246887728695403
# Prediction for 24980 user_id for item_id 95 is 0.937228296755497
# Prediction for 24980 user_id for item_id 96 is 0.8052369893912571
# Prediction for 24980 user_id for item_id 97 is 1.0069155927451956
# Prediction for 24980 user_id for item_id 98 is 0.2704537377576621
# Prediction for 24980 user_id for item_id 99 is 0.4081177865991284
# Prediction for 24981 user_id for item_id 0 is 0.8497789169043284
# Prediction for 24981 user_id for item_id 1 is 1.1823592983332105
# Prediction for 24981 user_id for item_id 2 is 0.9670250395837315
# Prediction for 24981 user_id for item_id 3 is 0.8866675340180601
# Prediction for 24981 user_id for item_id 5 is 1.489452191338977
# Prediction for 24981 user_id for item_id 8 is 0.8575834761955954
# Prediction for 24981 user_id for item_id 9 is 0.48622206755399994
# Prediction for 24981 user_id for item_id 10 is 1.0588827277741473
# Prediction for 24981 user_id for item_id 11 is 1.2364976834562522
# Prediction for 24981 user_id for item_id 13 is 0.6271752297540585
# Prediction for 24981 user_id for item_id 21 is 0.9804930400054759
# Prediction for 24981 user_id for item_id 22 is 1.237210735729232
# Prediction for 24981 user_id for item_id 23 is 1.5099745744155189
# Prediction for 24981 user_id for item_id 24 is 0.7932059095334357
# Prediction for 24981 user_id for item_id 29 is 1.0020188979972278
# Prediction for 24981 user_id for item_id 32 is 1.253605983687993
# Prediction for 24981 user_id for item_id 33 is 1.269531100826706
# Prediction for 24981 user_id for item_id 36 is 1.0147199875894348
# Prediction for 24981 user_id for item_id 37 is 1.1721750747096717
# Prediction for 24981 user_id for item_id 39 is 1.160384640987363
# Prediction for 24981 user_id for item_id 40 is 0.5704965008660673
# Prediction for 24981 user_id for item_id 42 is 0.7405451422133599
# Prediction for 24981 user_id for item_id 43 is 1.1846481480803392
# Prediction for 24981 user_id for item_id 44 is 1.0038816871519107
# Prediction for 24981 user_id for item_id 46 is 0.9516608003281747
# Prediction for 24981 user_id for item_id 50 is 0.836876402039183
# Prediction for 24981 user_id for item_id 51 is 0.36161889583328055
# Prediction for 24981 user_id for item_id 56 is 0.8802467559677922
# Prediction for 24981 user_id for item_id 57 is 1.453558082844436
# Prediction for 24981 user_id for item_id 58 is 0.8600168754356265
# Prediction for 24981 user_id for item_id 59 is 1.6992434124800841
# Prediction for 24981 user_id for item_id 62 is 1.0742971777089665
# Prediction for 24981 user_id for item_id 63 is 1.0088818134074387
# Prediction for 24981 user_id for item_id 66 is 1.380038579511808
# Prediction for 24981 user_id for item_id 69 is 0.46066966759463707
# Prediction for 24981 user_id for item_id 70 is 1.0194845683382188
# Prediction for 24981 user_id for item_id 71 is 0.4806739773747623
# Prediction for 24981 user_id for item_id 72 is 0.4436315717023971
# Prediction for 24981 user_id for item_id 73 is 0.5556309731820683
# Prediction for 24981 user_id for item_id 75 is 0.464308054512226
# Prediction for 24981 user_id for item_id 76 is 1.6367658535732121
# Prediction for 24981 user_id for item_id 77 is 0.7917655723910995
# Prediction for 24981 user_id for item_id 78 is 0.9477125485788362
# Prediction for 24981 user_id for item_id 80 is 0.43414160837434695
# Prediction for 24981 user_id for item_id 81 is 0.4010006824285225
# Prediction for 24981 user_id for item_id 82 is 0.9678928184270916
# Prediction for 24981 user_id for item_id 83 is 1.5396134468153146
# Prediction for 24981 user_id for item_id 84 is 1.208794064707506
# Prediction for 24981 user_id for item_id 85 is 1.0222674324885712
# Prediction for 24981 user_id for item_id 86 is 0.7529862082975491
# Prediction for 24981 user_id for item_id 87 is 0.5968438751962744
# Prediction for 24981 user_id for item_id 88 is 0.5714362740718374
# Prediction for 24981 user_id for item_id 89 is 1.118360243590869
# Prediction for 24981 user_id for item_id 90 is 0.9834765244595671
# Prediction for 24981 user_id for item_id 91 is 0.3828252120059687
# Prediction for 24981 user_id for item_id 92 is 0.26943581218804086
# Prediction for 24981 user_id for item_id 93 is 1.480117861433655
# Prediction for 24981 user_id for item_id 94 is 0.954650184107907
# Prediction for 24981 user_id for item_id 95 is 0.7584712074639975
# Prediction for 24981 user_id for item_id 96 is 0.9504337196898552
# Prediction for 24981 user_id for item_id 97 is 1.3576708548669474
# Prediction for 24981 user_id for item_id 98 is 0.5144910760956863
# Prediction for 24981 user_id for item_id 99 is 0.30050882529486367
# Prediction for 24982 user_id for item_id 71 is 0.6249422194782615
# Prediction for 24982 user_id for item_id 72 is 0.6530022647187534
# Prediction for 24982 user_id for item_id 73 is 0.6883961412470864
# Prediction for 24982 user_id for item_id 74 is 0.5300220159051482
# Prediction for 24982 user_id for item_id 75 is 0.7844648927657795
# Prediction for 24982 user_id for item_id 76 is 1.8787790067503691
# Prediction for 24982 user_id for item_id 77 is 1.0986735023092473
# Prediction for 24982 user_id for item_id 78 is 1.1192261190672954
# Prediction for 24982 user_id for item_id 79 is 1.801728623858549
# Prediction for 24982 user_id for item_id 80 is 0.5916100218260648
# Prediction for 24982 user_id for item_id 81 is 0.5978947795945146
# Prediction for 24982 user_id for item_id 82 is 1.222875415226398
# Prediction for 24982 user_id for item_id 83 is 1.8172476614322997
# Prediction for 24982 user_id for item_id 84 is 1.549898299483311
# Prediction for 24982 user_id for item_id 85 is 1.179182268072099
# Prediction for 24982 user_id for item_id 87 is 0.6586418944306976
# Prediction for 24982 user_id for item_id 88 is 0.691902972591701
# Prediction for 24982 user_id for item_id 89 is 1.323751664271702
# Prediction for 24982 user_id for item_id 90 is 1.3401191195376967
# Prediction for 24982 user_id for item_id 91 is 0.5786554845956646
# Prediction for 24982 user_id for item_id 92 is 0.4809754326851067
# Prediction for 24982 user_id for item_id 93 is 1.632529775526502
# Prediction for 24982 user_id for item_id 94 is 1.0988880203705913
# Prediction for 24982 user_id for item_id 95 is 0.93837953673559
# Prediction for 24982 user_id for item_id 96 is 1.1821513657471803
# Prediction for 24982 user_id for item_id 97 is 1.5525176377081538
# Prediction for 24982 user_id for item_id 98 is 0.647590137404385
# Prediction for 24982 user_id for item_id 99 is 0.5444462763988406

# %%
test_idx
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([70, 71, 72, ..., 97, 98, 99]))

# %%
num_iter = 100
hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
plt.figure()
plt.plot(np.arange(0, num_iter, 5), hist)
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.show()
# Out:
# Iteration 0/100:	MSE=25.674470
# Iteration 5/100:	MSE=24.480094
# Iteration 10/100:	MSE=23.834148
# Iteration 15/100:	MSE=23.178267
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-a67266c20be2> in <module>()
#       1 num_iter = 100
# ----> 2 hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
#       3 plt.figure()
#       4 plt.plot(np.arange(0, num_iter, 5), hist)
#       5 plt.xlabel("Iterations")
#
# <ipython-input-18-c60fc9aec2c6> in sgd(iterations)
#      29                 rating = user_ratings[user_id, item_id]
#      30                 if not np.isnan(rating):
# ---> 31                     err = train(user_id, item_id, rating)
#      32                     error.append(err)
#      33         mse = (np.array(error) ** 2).mean()
#
# <ipython-input-18-c60fc9aec2c6> in train(user_id, item_id, rating, alpha)
#       9 def train(user_id, item_id, rating, alpha=0.0001):
#      10     #print(item_id)
# ---> 11     predicted_rating = predict_rating(user_id, item_id)
#      12     err =  predicted_rating - rating
#      13     #print(err)
#
# <ipython-input-18-c60fc9aec2c6> in predict_rating(user_id, item_id)
#       4     user_preference = latent_user_preferences[user_id]
#       5     item_preference = latent_item_features[item_id]
# ----> 6     return user_preference.dot(item_preference)
#       7
#       8
#
# KeyboardInterrupt:

# %%
jester_nan.iloc[21944,4]
# Out:
# 1.46

# %%
df_items = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true')
df_users = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true', sheet_name=1)

# %%
df_users.set_index('User', inplace=True)

# %%
df_items.set_index('Movie ID', inplace=True)

# %%
df_items[df_items['Factor7'] == df_items['Factor7'].max()]
# Out:
#                          Title   Factor1  Factor2  ...  Factor13  Factor14  Factor15
# Movie ID                                           ...
# 8467      Dumb & Dumber (1994)  2.720287  1.21762  ... -1.240696   0.27991  1.616338
#
# [1 rows x 16 columns]

# %%
items_latent = df_items.drop('Title', axis=1).values

# %%
user_latent = df_users.values

# %%
user_latent.shape
# Out:
# (25, 15)

# %%
items_latent.shape
# Out:
# (100, 15)

# %%
def predict_movie_rating(user, movie):
  user_arr = df_users.loc[user].values
  movie_arr = df_items.loc[movie].drop('Title').values
  return user_arr.dot(movie_arr)

# %%
def top_n_recommendation(user, n):
  pred = {}
  for movie in df_items.index:
    pred[movie] = predict_movie_rating(user, movie)
  pred = dict(sorted(pred.items(), key=lambda kv: kv[1], reverse=True))
  movies = list(pred.keys())
  return movies[:n]

# %%
predict_movie_rating(4469, 14)
# Out:
# -0.015182451121203224

# %%
predict_movie_rating(4433, 274)
# Out:
# 0.6276484751025112

# %%
top_n_recommendation(4327, 2)
# Out:
# [597, 329]

# %%
top_n_recommendation(3947, 3)
# Out:
# [603, 604, 453]
